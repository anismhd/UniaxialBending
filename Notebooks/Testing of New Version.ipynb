# %%
import numpy as np

# %%
import sys
sys.path.append('/home/anis/GitHub/')

# %%
import UniaxialBending as ub
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
fname = '/home/anis/GitHub/UniaxialBending/PillaiEx4p16b.dat'
SECTION2 = ub.UniaxialBendingSection(fname)

# %%
T,C = SECTION2.axial_capacity()

# %%
c_strn = SECTION2.compressive_strain(0.5*C)
# Out:
# -0.002 0.0008592132505175986 0.003718426501035197 2962.368291871558
# Positive
# -0.002 -0.0005703933747412007 0.0008592132505175986 364.4795401465008
# Positive
# -0.002 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# -0.0012851966873706003 -0.0012851966873706003 -0.0005703933747412007 -1187.5911965549008
# negative
# ...

# %%
print(c_strn)
# Out:
# None

# %%
T
# Out:
# 2049738.9563839075
